# %%
import numpy as np
import pandas as pd

# %%
# 1. Veri setini yükleyelim
df=pd.read_csv("yz/turkey_car_market.csv")
# Veri Setinin ilk 5 satırına bakalım
df.head(5)
# Out:
#   İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0  27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1  16/06/2020   Acura             CL                    -     2015.0
# 2  14/06/2020   Acura             CL                  2.2     1994.0
# 3  11/06/2020   Acura             CL                    -     2013.0
# 4  11/06/2020   Acura             CL                  2.2     2010.0
#
#    Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# 0       Dizel       Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1       Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2  Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3       Dizel            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4       Dizel       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
#
#           Kasa Tipi      Kimden  Durum      Km   Fiyat
# ...

# %%
df=df.drop(['İlan Tarihi', 'Arac Tip Grubu', 'Arac Tip', 'CCM', 'Beygir Gucu', 'Kasa Tipi', 'Kimden', 'Durum' ],axis=1)
df
# Out:
#        Marka  Model Yıl  Yakıt Turu                Vites         Renk      Km  \
# 0     Jaguar     2017.0       Dizel       Otomatik Vites    Lacivert    26100
# 1      Acura     2015.0       Dizel  Yarı Otomatik Vites        Mavi   127000
# 2      Acura     1994.0  Benzin/LPG            Düz Vites     Turkuaz   175000
# 3      Acura     2013.0       Dizel            Düz Vites  Kahverengi      325
# 4      Acura     2010.0       Dizel       Otomatik Vites       Beyaz   207000
# ...      ...        ...         ...                  ...          ...     ...
# 9039   Tofaş     1994.0  Benzin/LPG            Düz Vites       Beyaz   121212
# 9040   Tofaş     1992.0  Benzin/LPG            Düz Vites         Bej    54000
# 9041   Tofaş     1993.0  Benzin/LPG            Düz Vites       Yeşil   135000
# 9042   Tofaş     1991.0  Benzin/LPG            Düz Vites     Kırmızı   250000
# 9043   Tofaş     1996.0  Benzin/LPG            Düz Vites       Beyaz       11
#
#        Fiyat
# 0     634500
# ...
